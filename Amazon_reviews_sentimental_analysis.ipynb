# %%
pip install azure-storage-blob
# Out:
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.22.0-py3-none-any.whl.metadata (26 kB)
# Collecting azure-core>=1.28.0 (from azure-storage-blob)
#   Downloading azure_core-1.30.2-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (42.0.8)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (4.12.2)
# Collecting isodate>=0.6.1 (from azure-storage-blob)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.28.0->azure-storage-blob) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.28.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-blob) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-blob) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-blob) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-blob) (2024.7.4)
# Downloading azure_storage_blob-12.22.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.9/404.9 kB 8.6 MB/s eta 0:00:00
# Downloading azure_core-1.30.2-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.3/194.3 kB 9.3 MB/s eta 0:00:00
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: isodate, azure-core, azure-storage-blob
# Successfully installed azure-core-1.30.2 azure-storage-blob-12.22.0 isodate-0.6.1

# %%
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
import pandas as pd
import io

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report,ConfusionMatrixDisplay
from sklearn import naive_bayes
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from sklearn.ensemble import RandomForestClassifier

# %%
connection_string = 'DefaultEndpointsProtocol=https;AccountName=venkat778;AccountKey=PJ1Zu8Ml5u6uZ9vzusOWecpg4dGIS1fVUdHICMuZP4jgprkE7rdLwUrF8+QgbCHksA3hGnI2yVY2+AStoQm8Qw==;EndpointSuffix=core.windows.net'
container_name = 'amazonreviews'
blob_name = 'Amazon_Reviews.csv'  # The name of your blob (CSV file)

# Create a BlobServiceClient object
blob_service_client = BlobServiceClient.from_connection_string(connection_string)

# Create a BlobClient to interact with the specific blob
blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)

# Download the blob data into a bytes object
downloaded_blob = blob_client.download_blob().readall()

# Convert the bytes object to a pandas DataFrame
df = pd.read_csv(io.BytesIO(downloaded_blob))

# %%
df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     11555559  R1QXC7AHHJBQ3O  B00IKPX4GY         2693241
# 1          US     31469372  R175VSRV6ZETOP  B00IKPYKWG         2693241
# 2          US     26843895  R2HRFF78MWGY19  B00IKPW0UA         2693241
# 3          US     19844868   R8Q39WPKYVSTX  B00LCHSHMS         2693241
# 4          US      1189852  R3RL4C8YP2ZCJL  B00IKPZ5V6         2693241
#
#                            product_title product_category  star_rating  \
# 0  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 1  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            3
# 2  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 3  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            4
# 4  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
#
#    helpful_votes  total_votes vine verified_purchase  \
# 0              0            0    N                 Y
# 1              0            0    N                 N
# 2              0            0    N                 Y
# 3              0            0    N                 N
# 4              0            0    N                 Y
#
#                                      review_headline  \
# 0                                         Five Stars
# 1  Lots of ads Slow processing speed Occasionally...
# 2                            Well thought out device
# 3  Not all apps/games we were looking forward to ...
# 4                                         Five Stars
#
#                                          review_body review_date  sentiment
# 0                                      Great love it  31-08-2015          1
# 1  Lots of ads<br />Slow processing speed<br />Oc...  31-08-2015          0
# 2  Excellent unit.  The versatility of this table...  31-08-2015          1
# 3  I bought this on Amazon Prime so I ended up bu...  31-08-2015          1
# 4  All Amazon products continue to meet my expect...  31-08-2015          1

# %%
df.columns
# Out:
# Index(['marketplace', 'customer_id', 'review_id', 'product_id',
#        'product_parent', 'product_title', 'product_category', 'star_rating',
#        'helpful_votes', 'total_votes', 'vine', 'verified_purchase',
#        'review_headline', 'review_body', 'review_date', 'sentiment'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30846 entries, 0 to 30845
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   marketplace        30846 non-null  object
#  1   customer_id        30846 non-null  int64
#  2   review_id          30846 non-null  object
#  3   product_id         30846 non-null  object
#  4   product_parent     30846 non-null  int64
#  5   product_title      30846 non-null  object
#  6   product_category   30846 non-null  object
#  7   star_rating        30846 non-null  int64
#  8   helpful_votes      30846 non-null  int64
#  9   total_votes        30846 non-null  int64
#  10  vine               30846 non-null  object
#  11  verified_purchase  30846 non-null  object
#  12  review_headline    30844 non-null  object
#  13  review_body        30842 non-null  object
#  14  review_date        30846 non-null  object
#  15  sentiment          30846 non-null  int64
# dtypes: int64(6), object(10)
# memory usage: 3.8+ MB

# %%
# adding a sentiment column to classify reviews as Positive or Negative
# Positive = 1
# Negative = 0

df['sentiment'] = np.where(df['star_rating'] == 5.0, 1,
                           np.where(df['star_rating'] == 4.0, 1, 0))

# %%
# get unique values of product title column
df["product_title"].unique()
# Out:
# array(['Fire HD 7, 7" HD Display, Wi-Fi, 8 GB'], dtype=object)

# %%
# choose a particular product for analysis
prod_hosa = df.loc[df["product_title"]=='Fire HD 7, 7" HD Display, Wi-Fi, 8 GB']
prod_hosa
# Out:
#       marketplace  customer_id       review_id  product_id  product_parent  \
# 0              US     11555559  R1QXC7AHHJBQ3O  B00IKPX4GY         2693241
# 1              US     31469372  R175VSRV6ZETOP  B00IKPYKWG         2693241
# 2              US     26843895  R2HRFF78MWGY19  B00IKPW0UA         2693241
# 3              US     19844868   R8Q39WPKYVSTX  B00LCHSHMS         2693241
# 4              US      1189852  R3RL4C8YP2ZCJL  B00IKPZ5V6         2693241
# ...           ...          ...             ...         ...             ...
# 30841          US     44834233  R366C7ARIWLN7R  B00IKPW0UA         2693241
# 30842          US     13376158  R35PL0AOCUXLU9  B00IKPYKWG         2693241
# 30843          US     40485963  R18ZJVY86AUFII  B00KC6XV58         2693241
# 30844          US     33485035  R36QVLQXMCZRSJ  B00IKPYKWG         2693241
# 30845          US      7015231  R1MWVQUDBUADGE  B00IKPYKWG         2693241
#
#                                product_title product_category  star_rating  \
# 0      Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 1      Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            3
# 2      Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 3      Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            4
# 4      Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# ...                                      ...              ...          ...
# 30841  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 30842  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 30843  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 30844  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            4
# 30845  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
#
#        helpful_votes  total_votes vine verified_purchase  \
# 0                  0            0    N                 Y
# 1                  0            0    N                 N
# 2                  0            0    N                 Y
# 3                  0            0    N                 N
# 4                  0            0    N                 Y
# ...              ...          ...  ...               ...
# 30841           3720         3875    N                 Y
# 30842           2716         2849    N                 Y
# 30843           1525         1629    N                 Y
# 30844            143          163    N                 Y
# 30845              2           10    N                 N
#
#                                          review_headline  \
# 0                                             Five Stars
# 1      Lots of ads Slow processing speed Occasionally...
# 2                                Well thought out device
# 3      Not all apps/games we were looking forward to ...
# 4                                             Five Stars
# ...                                                  ...
# 30841  A great upgrade for me from an older Kindle Fire!
# 30842                               Great Value for $139
# 30843                   Even grandma has it figured out!
# 30844                        The Honda Accord of Tablets
# 30845                                    won't regret it
#
#                                              review_body review_date  \
# 0                                          Great love it  31-08-2015
# 1      Lots of ads<br />Slow processing speed<br />Oc...  31-08-2015
# 2      Excellent unit.  The versatility of this table...  31-08-2015
# 3      I bought this on Amazon Prime so I ended up bu...  31-08-2015
# 4      All Amazon products continue to meet my expect...  31-08-2015
# ...                                                  ...         ...
# 30841  [[VIDEOID:moP3B6GS5RL8LY]]I purchased the orig...  03-10-2014
# 30842  I'm writing this review with the benefit of be...  03-10-2014
# 30843  I purchased this Kindle for my grandma, becaus...  03-10-2014
# 30844  I bought my tablet Fire HD 7 at Best Buy on th...  03-10-2014
# 30845  Am impressive piece of hardware for the $. No ...  03-10-2014
#
#        sentiment
# 0              1
# 1              0
# 2              1
# 3              1
# 4              1
# ...          ...
# 30841          1
# 30842          1
# 30843          1
# 30844          1
# 30845          1
#
# [30846 rows x 16 columns]

# %%
# #split data-set to train and test

X = prod_hosa.drop("sentiment",axis=1)
Y = prod_hosa['sentiment']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)

# %%
# function to remove html elements from the reviews
def removeHTML(raw_text):
    clean_HTML = BeautifulSoup(raw_text, 'lxml').get_text()
    return clean_HTML

# %%
# function to remove special characters and numbers from the reviews4961
def removeSpecialChar(raw_text):
    clean_SpecialChar = re.sub("[^a-zA-Z]", " ", raw_text)
    return clean_SpecialChar

# %%
# function to convert all reviews into lower case
def toLowerCase(raw_text):
    clean_LowerCase = raw_text.lower().split()
    return( " ".join(clean_LowerCase))

# %%
# function to remove stop words from the reviews
def removeStopWords(raw_text):
    stops = set(stopwords.words("english"))
    words = [w for w in raw_text if not w in stops]
    return( " ".join(words))

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
X_train['review_body'] = X_train['review_body'].astype(str)

# %%
# X_training clean set
X_train_cleaned = []

for val in X_train['review_body']:
    val = removeHTML(val)
    val = removeSpecialChar(val)
    val = toLowerCase(val)
    removeStopWords(val)
    X_train_cleaned.append(val)
# Out:
# <ipython-input-39-c2a805237a43>:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_HTML = BeautifulSoup(raw_text, 'lxml').get_text()

# %%
# X_testing clean set
X_test_cleaned = []

for val in X_test['review_body']:
    val = removeHTML(val)
    val = removeSpecialChar(val)
    val = toLowerCase(val)
    removeStopWords(val)
    X_test_cleaned.append(val)
# Out:
# <ipython-input-39-c2a805237a43>:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_HTML = BeautifulSoup(raw_text, 'lxml').get_text()

# %%
X_train_cleaned
# Out:
# ['love it',
#  'love my fire hd',
#  'i like the fire but i had some problems using the books i did not know to press on the side to get the first part of a book',
#  'nice tablet but doesn t allow google play amazon has stopped the fix called rooting so that you can use the play store',
#  'love it',
#  'love this',
#  'my year old loves his new fire',
#  'awesome i just wish you could put what you want on the main screen like a background picture like on an iphone not what app or book that you were in last i m sure it will happen though love my kindles anyway',
#  'i m sure the device is just fine the problem is the user i find it confusing and perplexing and not easy to use',
#  'a nice tablet for the price the apps available in amazon are limited but it works well for what i use it for which is reading online and streaming music to my stereo via bluetooth',
#  'love it love it what s not to like everything literally at your fingertips user friendly price is right and you look cool using it we re old and have nothing but fun with our fire every day two arthritic thumbs up',
#  'absolutely love it',
#  'excellent product',
#  'its awesome love it',
#  'we purchased this in anticipation of a cross country road trip i m in the navy and we move every few years but this will be the first cross country move with a child we also purchased a case for it since toddlers tend to throw things around especially expensive ones having this will definitely help out with the ability to download and save sesame street videos my son seems to enjoy it but after about minutes or less he gets bored with it if there are other people around which is probably a good thing in the car he has a longer attention span with the kindle so i am hopeful for our move i ll update after we move to see how effective the kindle was',
#  'love everything about it except the ads when i boot it up i guess special offers means annoying ads when you turn it on',
#  'great value for the one day discounted price',
#  'great',
#  'i have never had a hand held device other than my cell phone and i really wasn t all that excited about a kindle until i decided to ask for one for christmas i am so glad i have this thing i can take it upstairs and leave my laptop downstairs if i want to research on the net or shop or it has taken the place of my sudoku books that i take to appointments restaurants or anyplace i might have to sit and wait it takes very clear photos and also videos i ve been able to figure out the solution to any problems i have had which is saying a lot because i m a year old nerd grandmother if i can handle it i would think almost anyone can',
#  'the amazon store is terrible beyond terrible hardly any apps that i actually use returned the fire hd and bought a lenovo tablet',
#  'my main complaint is that gb is not enough memory to store anything on this kindle and you can t add any more memory sure it s all on the cloud your books your tunes etc but what if you don t have constant access to the internet you re out of luck i use the kindle most when i travel and the lack of sufficient memory limits what i can enjoy imo they shouldn t sell anything smaller than gb also what is with the usb charging cord it barely reaches from the table to the floor which makes it virtually useless it s a full two feet shorter than previous models',
#  'love it',
#  'it made a great christmas gift for my daughter',
#  'i just love everything i can with my kindles',
#  'didn t meet my expectations the nd generation was much better and easier to work with',
#  'for the price can t beat it love mine',
#  'this small and very durable tablet has proven to be very convenient especially when it is combined with the amazon prime cloud services excellent photo display',
#  'i love reading with the fire',
#  'daughter loves it and won t put it down',
#  'i really like the look feel and sound of this device but i primarily bought it for display mirroring which the amazon site clearly says is available i looked at all the amazon help sections read the owner s manual and have contacted amazon about this missing feature i feel like this was sort of a bait and switch kind of deal i got the device during the cyber sales and thought i was getting a fully featured device but it doesn t look like it instead it looks like key features are missing it s not as if i don t know how to set up device mirroring i ve done it effectively with my kindle fire hdx and with apple products this just appears to promise something it doesn t deliver however if the mirroring isn t important the performance on this device is excellent everything loads quickly even the special offers aren t that annoying but i really am missing the display mirroring and probably will have to send this back update the amazon help response was sort of odd i asked several questions but only one of those questions was really answered in the first round what kindles actually have display mirroring however i did find out that you can hardwire your hd to create mirroring display using amazon hdmi adapter for fire tablets th generation and an hdmi port if you have one on your tv be careful with older kindles the adapter doesn t work i am still testing to see how using the adapter affects the battery life of the fire with the hdx and wireless mirroring you can have the power cord attached so that you re not running the battery down while mirroring i m not sure that an hdmi connection like a usb connection to a power source with other computer devices will also power the kindle i doubt it but if the kindle will run for a decent length of time on battery this may not be an issue amazon could be much more helpful in describing how mirroring works with each device and what accessories are needed for each',
#  'great deal for a great price',
#  'this is my second kindle fire and i love it i had the original and decided to upgrade to the latest version this one includes the ads and i don t really see an issue with them at all it was worth the savings',
#  'purchased this mainly to play blizzard s hearthstone virtual collectable card game though the game first claims that it is below recommended requirements for the game i ve had zero issues and it s a great device for this game it s also been great for consuming media in bed or on the toilet and has been a great companion to my fire tv stick',
#  'this device is everything i expected it to be i can do everything i used to do on my laptop plus take photos like i used to on my smartphone i must admit that i have been using it as an ebook more than anything else since i purchased it because there s a nice selection of kindle ebooks available for free on amazon the fire stick app is also a nice feature i have only had my fire hd for a week and i m still checking out all of it s features however i m very pleased with my new tablet so far',
#  'i should have bought the samsung',
#  'yes this was everything that i was looking for',
#  'very pleased',
#  'great product beautiful screen resolution',
#  'exceeds expectations',
#  'crisp screen imagines clean lines fast response i love this easy peasy to use sitting in the middle of my bed im surrounded with a lap top an android tablet myfire a smart phone hard back and paperbacks i think i have every ones business efforts covered and no guilt for me',
#  'an excellent product i use every day',
#  'the fact that you cannot personalize the kindle and are bombarded with constant ads is very bothersome and to think that to stop the ads on locks creen you have to pay a one time fee is degrading save your money for a more customer friendly device believe me it lack a lot of think it is very limited',
#  'all good',
#  'love it',
#  'just received this the other day and i love it i have a ton of e books that i transferred over without a hitch super fast and great clarity',
#  'i love love my kindle fire hd didn t expect it to be this good but it will buy this again in a heartbeat',
#  'i ll give fire hd hd display stars i m very happy with my purchase',
#  'we originally bought a first generation kindle fire and this new one works very well and has a very nice display very fast compared to the old kindle fire',
#  'love my kindle this is my second one wore out the first one',
#  'love it very intuitive',
#  'battery does not seem to last',
#  'like it very much comparable to the i pad',
#  'loving it so far',
#  'we love our kindles this is the third kindle we get great tablet for an awesome price love that there is a camera on this one',
#  'it is an okay tablet as far as for reading goes if you want to play games or do anything else on it it gets a bit warm as you use it but i don t mind it for the main reason i got it so i don t have to read on my phone any longer if you want to play your facebook games or any other game you need to go with another tablet there is also a problem with the tablet locking up and having to reboot it i think i will end up buying a different tablet and replacing it with another brand even at price it wasn t worth what i paid as often as i am having to shut it down',
#  'i really like the fire hd the display area is just the right size for me price was right i m very happy with my kindel',
#  'my wife loves it',
#  'love it',
#  'amazing instrument replaces my year old kindle i m still exploring what it will do',
#  'this is a great tablet very nice picture apps and videos play awesome for the price you can t beat it my daughter loves it',
#  'love it have no complaints',
#  'nice clear and bright display',
#  'good tablet except their is too much glare when viewing websites and reading e mails especially outside otherwise good tablet for the price',
#  'i love this product however the battery power runs out quickly i only get around hours use and the battery is dead and i have to charge it again that is very disappointing i don t think i would be able to watch a whole movie without plugging it in or recharging it before it s over',
#  'this was a surprise gift and it is wonderful not sure how i lived without it',
#  'love it i ve had some technical glitches but all were easily solved books music movies shopping social media camera it has everything',
#  'love this kindle fire glad it connects to the internet and not just to read books small enough to fit in my purse yet large enough to read easily highly recommend',
#  'i cannot express to you how horrible this tablet is it freezes up all the time the battery dies almost on a daily basis many of the buttons only work when they want to the volume is very low and goes in and out and now the headphone jack doesn t work there are so many times where i just wanted to throw this piece of crap on the ground and watch it smash into a pieces i really wish i would not have wasted my money on this horrible device',
#  'i love it',
#  'just didn t like it',
#  'not much of a step up from the previous years offering the cameras are very low resolution so don t expect to be wowed by the images you ll snap my year old canon point and shoot has the same pixel count sadly it takes a better picture due to pixel spacing and considering the camera and quad core processor are the only big advances i have to say no changing the layout of the buttons sucks too i have to buy all new cases what s up with that',
#  'take it to school watch hulu and other shows play games read it is invaluable',
#  'this is the only item i have had problems with after only a couple weeks it isn t working trying to get info to return it now has anyone else had problems',
#  'love it',
#  'love the kindle fire fast with such a fantastic screen',
#  'my son loved it he read books before bed on the first night awesome tool to get your kids reading',
#  'first tablet for me i love it easy to use lots of fun free aps the sound is great very happy',
#  'i love it',
#  'i love my fire hd and use it every dsy',
#  'great all i could have wanted and more',
#  'i really liked my new kindle fire until it crashed two months later i had power when i turned it off and six hours later i could not turn it back on charging did not work holding the power button nothing i spent an evening with amazon kindle support on the phone and they were absolutely no help they just told me there was nothing they could do now i am told by amazon that i have to wait weeks for a replacement because they are so popular and are backordered not real impressed with kindle or amazon',
#  'i am still getting used to it i like all the features so far but i wanted to know something about my other kindle i ill probably go to the website and maybe talk to customer service',
#  'love these kindles we didn t care what color we purchased for our girls and because we knew we were going to put solid waterproof drop proof cases on them poetic fires so the color didn t matter the yellow isn t my fave but with the cases on you have no clue what color it is anyway we didn t want to buy them the kids version kindles b c they re limited to what can be downloaded and such instead we purchased of these and added child profiles to them this way i can use the kindle whenever they aren t using them and download things in the admin profile for myself that might be inappropriate for them and password protect the admin profile they have passwords for their profiles as well to lockout intruders from using the kindle all in all these are fabulous you can set turn off times reading limits and so on there are always unlimited free app downloads on amazon available much of which are their faves anyway i e doc mcstuffins abcmouse starfall and so on we re so thankful for these kindles and would certainly recommend them to parents who are tired of sharing their smart devices with their kiddos a great app capable product suitable for children that doesn t bust your budget like an ipad',
#  'used this to replace on older version of the kindle this one is much better and with the backlight makes reading easier in darker settings',
#  'love the fire i was using my son s school issued older generation fire and fell in love my husband bought me this one for christmas two things i wish though that the battery lasted longer and that the charging cord was longer like the older generation kindles have',
#  'given as a gift unable to acces computer with new kindle as computer is windows xp customer service was great',
#  'absolutely love fire hd',
#  'really nice and easy to use',
#  'i love it',
#  'i ve wanted a kindle for years and when my son surprised me with an early christmas present i was a bit overwhelmed i have arthritis and peripheral nerve damage in my hands which has made holding a book quite painful i have always had a voracious appetite when it came to reading and my amazon kindle fire has enabled me to return to my first love the adventure of the written word',
#  'this is my third kindle the smaller size fits in my purse and is small enough to read in bed i like it',
#  'i love this little guy it is easy to pack and travel with i can do just about anything with it from read a book to look up a restaurant',
#  'this product was easy to setup easy to use it is as good as they say it is very happy with it i browse the internet do email good product',
#  'finally retired my old kindal new is awesome',
#  'i ordered it received it last week and now you offer off',
#  'love it does everything we wanted and it s small enough to travel with without being to bulky',
#  'had a standard kindle upgraded to fire and i am really enjoying it',
#  'i now have two fires and i love this one most much faster and i like the way the apps can be located much like the ipad',
#  'better than i expected i have one that is a couple years old it doesn t even compare',
#  'this was a great deal for',
#  'love our kindles',
#  'compared to an ipad there is no comparison the mini ipad wins hands down sent the fire hd back the same day it arrived i took comparison photos of my son the fire hd color was washed out overall i was very disappointed',
#  'still trying to figure it all out',
#  'i bought this as a replacement for an older kindle fire that was stolen the clarity is great but the os tends to run a little bit slowly when switching apps from book to web for example i have a minimum number of apps on it my kindle is primarily for reading not movies or games overall kindle still suffers from a lack of apps no chrome etc there really is no reason why at this point the most popular apps aren t available for the kindle fire',
#  'unit locked up can t cannot use it',
#  'does i wanted it for',
#  'i dont like that all my games on my phone cant go on my fire but most of all my favorite ames can also my littke brothers lije to play on free time which is a great app for them and me the only other thing is that the battery drains really fast but other than those fault its great',
#  'i received the fire hd for christmas and love it i love to read and this is my constant companion my husband picked the perfect gift and it has been enjoyed since i received it my grand kids are having a blast with the camera option and i have a gallery of grandkid selfies',
#  'no substantial difference from the hd there is no noticeable difference in the screen size and i expected a longer lasting battery which this version did not offer this is my fourth kindle and i expected more',
#  'i love my kindle',
#  'love the fire this is our second one it is used by mom for email and web access it is easy for her to operate charge and carry around graphics are good',
#  'i like this product but not being able to connect it to my tv with an hdmi cable and adaptor was very disappointing',
#  'why does please connect to the internet to run this app come on all the time',
#  'exceeds expectations',
#  'easy to use',
#  'i love my fire i use it for emails and facebook maps looking up information still getting use to what i need and want on this little tablet tks',
#  'i bought this for my husband as he reads his daily bible with it he had another brand but loves this one problem is he won t let me download and use it to protective thanks for a great item',
#  'i was sorry that it will not read from my kindle ebook library i was told that it would',
#  'i like kindle any way but really love that the camera was added and different colors also only other thing is i went up on the gb for the first one i purchased love love love it any the price was great',
#  'love it',
#  'love my new kindle just downloaded a book and love the extra functionality of reading on a tablet enjoying the washington post app stories and design are enriching and engaging it s my go to for in depth news coverage the only negative is that the silk browser can be wonky on some websites otherwise love it',
#  'couldn t ask for anything better for the price i love it ok',
#  'as expected a great buy',
#  'the fire hd is nifty i use it to read books the light stays bright and the battery life is good',
#  'looks great',
#  'it is for my wife a little akward to use at first but she loves it',
#  'love it',
#  'i bought this for my son as a christmas gift and we both love it',
#  'love it',
#  'great to watch movies and get email and surf web',
#  'delivered in a few days for daughters birthday she loves it especially the cobalt blue color',
#  'it',
#  'great tablet i m yo and i m new to this tablet thing so i thought starting off with something adequate to my needs great thus far the only issue i have is that i cant change the screen saver picture or probably i haven t figured it out',
#  'my year old granddaughter loves it',
#  'the fire does everything as it was advertised to do the hd screen quality is excellant i am very happy with my fire and i have no doubt that as i use it more and learn about learn to use the many features i will enjoy my fire more when i went out shopping on black friday for a tablet this was not the one i had set out to purchase the ones on sale were sold out that acctually worked out in my favor the cost of the fire was twice as much as the other i was looking to purchase rather than getting average tablets i got great one i will recommend this tablet to all who are shopping for one',
#  'the hd does everything well for the price and it was a great bargain on prime day of the people who have complaints did not first research what this tablet can and cannot do they complain about not having all google apps available or not being able to personalize the look of the home screen etc this tablet does everything i m interested in i don t need a bunch of apps and games i just want a device that can surf the net get email play music and videos sound and picture quality are excellent and store my kindle books i plan to leave all my content on the cloud and only download a book or two at s time ditto for videos i will stream via wifi unless i need a few hours of content for vacations granted the gb model doesn t hold much video content but enough for the two or three times a year i want to download a few tv shows or a couple movies in sd if you plan to routinely download hours worth of offline content make sure to buy the gb because most of the gb model s memory is used by the operating system and preloaded apps that cannot be deleted for outdoor reading you need an e ink reader without a reflective screen so don t buy this or any other tablet if you primarily plan to read at the beach i have the basic entry level kindle for outdoor indoor reading i find this model easy to use it s not hard to figure out it provides new user tips on the screen and there is a user guide loaded on the device as well mine has the special offers on the lock screen i dont find it objectionable you can t turn those initial ads off but in the settings you can turn off ad recommendations and that will eliminate any additional ads elsewhere again know what you re buying so you don t complain later about the ads on the lock screen i love this tablet the sound is amazing for a device of this size the picture quality is great i bought an inexpensive book like leatherette cover to protect it and the cover also serves as a means to stand the tablet up in landscape mode so i don t need to hold onto it consequently i don t care what color the tablet is the color barely shows i highly recommend the hd i think it s an amazing product and i m very satisfied with it',
#  'piece of junk could not connect to wifi tech support never got back to me got a refund luckily but stay away from this',
#  'i absolutely love my kindle i don t know how i got along without it before the inch screen is great for reading or browsing the internet it s really fast and i have no complaints about it would definitely recommend',
#  'smooth transaction',
#  'great job amazon',
#  'the fire hd is my third kindle however i m not sure i will ever purchase another one my freezes up all the time it frequently will not turn to the next page of a book all in all i am frustrated on the plus side the picture quality is over nice just wish it worked as nice as my other kindles',
#  'i bought it for my wife and she loves it light and easy to read and use',
#  'great',
#  'really liked the larger screen from the',
#  'love this kindle best by far',
#  'so so i do not like the constant advertising',
#  'finally replaced my old and i mean old kindle the fire hd is perfect for me and my needs i also have a ipad and i wish i would have gotten the kindle fire hd a few years ago instead of the ipad',
#  'i m really enjoying this christmas gift',
#  'have a larger ipad but am enjoying this kindle more runs faster appears sharper lighter to carry around just a handy little tablet',
#  'great sale price',
#  'i love this kindle fire it takes really great video and pictures was convenient to carry and very user friendly i would recommend',
#  'i have not completely examined this product i bought it for another person seems to be working as expected',
#  'my husband and i both have one and love them',
#  'bought this after drowning my fire hd i actually like the better its lighter and easier to hold don t know what the special offer is though',
#  'love it',
#  'easy to use for my year old son who loves to play educational games puzzles sometimes angry birds too we have a kindle from witch the whole family uses it s having charge issues now so this fire hd is a nice updated model and it takes pictures videos inexpensive too planning on buying a third for my year old mom wonderful reliable thanks amazon',
#  'the fire hd is great except when i try to take photo it s upside down while filming when i m finished filming taking a photo it displays correctly i m taking it back to radio shack my e geek says the camera was probably installed upside down thank you',
#  'fire hd is a great tablet i have a fire hdx that is about a year old and i was able to restore the last backup from the hdx to the hd everything was up and running in less than an hour i got the hd with ads and it s not a problem the only time i see the ads are at startup i recently got an amazon echo have been reading a lot of e books and also have been using amazon prime music a lot now i don t have to worry about whether the battery is getting low i always have a fully charged tablet the display is very clear response time is excellent and the battery life is great an excellent purchase for the price',
#  'the best kindle yet have to hand it to you guys this time excellent this is the th or th kindle i have purchased ha they make great gifts for anyone on your list',
#  'i bought this for my husband not knowing if he would like it or no he loves',
#  'i love my kindle fire hd it is everything i could have asked for i am thrilled with it i can t wait to continue using it and see what all it can do',
#  'great device for traveling',
#  'love the kindle fire',
#  'my first kindle from years ago was great this new fire hd is fantastic and unlimited as to how i am using it my only negative is that it does not come with a manual which would be a good help in setting up everything i was used to in the old kindle but i am enjoying the camera skype setup i have absolutely no complaints with this new fire hd',
#  'not great freezes games fail to upload does not sync to last page read in apple devices battery does not last',
#  'love it i upgraded to the fire from the paperwhite while the paperwhite is excellent as a straight reader i still have mine the fire offers so much more i ve been using it instead of my ipod to listen to music while at work so i have one less device to carry i love that there is a separate place for documents pdfs etc than for books makes it easier to find and manage my documents i love the ease and speed with which i can move things from cloud to fire and vice versa i love the capabilities in shopping which allow me to access more areas of amazon than the kindle store on my paperwhite did i can order physical items rather than being limited to just digital and track orders very convenient i love love love streaming music and movies thousands and thousands free because i am a prime customer prime and fire make a very a happy pair it would be a plus if it had more storage space i have to be careful not to put several seasons of tv shows like downton abbey d on it or i run out of space videos take up much more space than books and music on the other hand having limited storage keeps me from cluttering it up keeping a limited number of items actually on the device makes housekeeping easier wonderful device love it',
#  'beware operating system is not android and many i m talking a lot google play apps are not compatible the screen freezes and the unit has to be restarted more than i would expect a days old to be',
#  'very happy with it',
#  'completely unreliable product and one amazon will not fully back up in december we bought the kindle fire hd march it had to be replaced and now less than a year later we began to have issues with it connecting to the wi fi after over hours with tech support no one can figure out what is going on with it come to find out our replacement kindle fire did not include a year warranty way to back an unreliable product amazon so the high level tech support graciously offered us a discount on a returned repackage kindle for wait for it off yes off the price of what i could get a new kindle for whoa thanks so much oh and to top it off to get that awesome deal which you could get more of a deal when the kindle fire deal of the day is ran you have to send the other kindle back really so in all there would be between a investment for only one kindle fire i knew the kindle fires were not reliable as amazon had to replace our first kindle fire non hd twice due to glitches but at the time amazon had done a great job of backing their product now not so much will no longer be recommending this product to anyone',
#  'disappointed by the glare not able to use outside',
#  'i don t need to buy an expensive tablet when this does exactly what i need amazing battery life i recommend the kindle to everyone just wish the app store had more to choose from shipped incredibly quickly',
#  'a nice improvement from the kindle fire nice and lightweight keep improving',
#  'l love it',
#  'very readable',
#  'works well compact and easy to use',
#  'easy to use',
#  'very good more than satisfied',
#  'my th kindle hope this one s charging port holds up',
#  'my son loved it as his christmas gift told me i should buy one for myself',
#  'works well easier for travel',
#  'the tablet i have ever purchased it does all the things i will ever need',
#  'i love it it s beautiful the stand is great',
#  'i loved it i bought one for my son and myself to use and he loves it as well',
#  'i love it still getting comfortable with it',
#  'love it',
#  'excellent',
#  'i like the tablet but it freezes up when i play some games on it it is a lot lighter than the first amazon fire tablet that i bought a couple of years ago i will be interested to see if it is as durable the screens are more complicated but i guess i just got to get used to it i think the older ones were easier to use i also miss the charge light the new ones do not have it',
#  'i love my fire it is the perfect size for holding while reading i can get a lot of books free and at low cost so i never run out of reading material i have really enjoyed reading my free subscription to the washington post the fire has good speed to check my emails to shop and just to browse the internet there is a lot of apps and games for the fire',
#  'i am having problems transferring my itunes and pictures from my old divice color is very nice on the fire hd and it takes beautiful photos',
#  'i got this replace my kindle the original this is a vast improvement over the original everything is better and clearer i am still playing with and learning all of it s features lots of fun and this from a year old man',
#  'great',
#  'poor support spent minutes on the phone was told they would call me back i m still waiting',
#  'my kids loved their new kindle fire very happy with my purchase fast delivery and great quality',
#  'i got a gift certificate for my birthday and this seemed like the prefect fit i was looking for a tablet and this fit the bill the picture is great and the wifi is fast the only drawback i ve found so far is that some apps don t work on it like instagram i found a way around it but still also i write scripts and i have yet to figure out how to get pdf files from my e mail into my book library beyond that my biggest problem is that it does almost everything my iphone does i just need to remember that i can do all of that from my fire now',
#  'best purchase i ve made in a while',
#  'extremely pleased with the kindle fire hd i expect to use this mostly for reading but i am very pleased with how well integrated the web browsing is i like the availability of apps on the device however the photography apps which would interest me the most are severely hampered by the mp camera built into the unit all in all i am very happy with this new kindle and expect to get as much use from it as i did from my old kindle years old',
#  'i am a techie and work with computers every day i have a desktop laptop dell tablet and you know sometimes all you need is simple love my kindle fire hd use it most every day i use it for e mail news updates browsing to research items you tube to help me fix my tractor at home and for digital magazines i check out from our library it is light easy works great and the best part no windows updates',
#  'so far it seems to function fine however i thought i was buying an g device the device displays about g and when i called tech support they tell me had i read the specifications it would tell me only g were available for the user they were never able to show me the g of storage and i feel defrauded',
#  'i was hesitant about getting a kindle because i wasn t sure i would use it very much it turns out i use it all the time not only for reading but for email web surfing and watching my favorite shows i love it and now i don t know what i did without it',
#  'gud',
#  'my husband liked it kind of confusing how to set it up',
#  'i m enjoying it very much',
#  'love this new generation fire fits in your hand',
#  'good quality',
#  'i love this i got one for my son and daughter also and my son said that if he got any type of notepad it would have been this one it s easy to use small and easily carried',
#  'the display is flawless the price is right and i should have gone with the largest one they had but there was too much of a price gap to basically just for a larger screen the only other complaint is the amazon app store it s not as good as google play so you re stuck unless you find a work around without rooting the device',
#  'i am very happy with this product convenient and easy to use',
#  'awesome nuff said',
#  'love the kindle battery charge seems shorter than it should be have to recharge twice a day have to turn off kindle if i want to get out of book i am reading otherwise it is a great item',
#  'i got one of these for each of my kids i love the parental controls they are so easy to set',
#  'great tablet only gripe is that you can t download google play apps',
#  'not as user friendly as earlier model',
#  'a nice upgrade from my then again it was time for a new one my husband got this for me in pink because it s a favorite color of mine but it will be hidden when i put a case on it it was a sweet thought though',
#  'it was a christmas gift so i am beyond grateful for my fire hd it s not so easy to navigate so i find that right now i am still reading on my old kindle and still using my laptop for emails facebook most of the time i expect to get used to it as tiime goes on hopefully',
#  'this was a gift and am still feeling my way not overly impressed at this point',
#  'i love it',
#  'nice size still learning new things about it daily',
#  'the battery life isn t comparable to the fire hdx there is no mirroring function on this new kindle like everything this new model isn t quite the same and there is a learning curve the biggest disadvantage of the new kindle is the missing mayday feature but i like it and recommend this to anyone looking for a non complex tablet',
#  'was a gift for me am very happy except for needing some sort of training manual the person who bought it for me doesn t have time to teach me so all i can do is trial an error i am a senior citizen',
#  'pretty good having no problems yet and you can t beat that price',
#  'great cover for my fire',
#  'best thing i did was buy this for reading purposes you just download a book and read it works in all those places that have wi fi so it is easy to take along',
#  'my granddaughter loves it',
#  'nice love these things',
#  'it was exactly what i wanted and as described i got a good price and also and also a bargain on prime very satisfied',
#  'i love this device it s easy to use fast and efficient just what i needed',
#  'sharp crisp display and lightening fast graphics absolutely fantastic for the price',
#  'i am enjoying the kindle fire i am not very hi tech so i have a lot to learn',
#  'my son dropped his fire hd so we ordered this one fire hd has much better features than the hd and is also easier to navigate the best part of it all was that he was able to retrieve all his books music and games through cloud he loves it however he wishes it was the same size as the hd',
#  'easy to use great graphics',
#  'it is amazing i love it',
#  'i am enjoying the bright colors and the back light it is so much more advanced than the old old one i ve had for years still working on moving around on it but it s great',
#  'love it',
#  'amazing tablet for the price i was happily surprised at the beautiful screen quality for watching videos reading and viewing images',
#  'everything is fine arrived with all parts and parcels intact plugged it right away few hours later turned it on to a bright clear screen most of my items from old kindle had been transferred to new kindle',
#  'i m loving it',
#  'i had a black fire for several weeks then one day i took it with me in the car on a hospital visit and it turned blue never noticed the actual color using it around the house strange amazing',
#  'not worth wasting your money on it s slow and has a tendency to freeze up should have cancelled my order when i was informed amazon sold me a product they didn t have in stock at the time of purchase',
#  'first tablet not very happy can t play games that requires flash player other games freeze up picture quality is ok but not good to do ebay with was good learning on it but think i need to replace with better tablet to get better features that i enjoy also would be nice if it charged faster',
#  'i had an older toshiba tablet before this and i have to say that the kindle is bay far a better choice the main reason that i did get the kindle fire is i wanted to sign up for amazon prime and with my old toshiba tablet i could not watch movies or get books from my amazon prime account but i could get music for certain stuff the toshiba was not a supported device so i felt it was time to upgrade so far i have not ran into any issues with the kindle fire hd watching movies and reading books on it is great i feel that the size is a good balance between small enough to take with you and not get in the way and big enough to still be pleasant to watch movies on and read books the audio sounds really good even though i use earphones most of the time',
#  'love my new fire quick to set up easy to use all of my info easily transferred from first gen to this one thanks',
#  'great tablet few advertismens interrupt my reading sometimes',
#  'is an ok tablet but was expecting regular android not amazon s less than version was purchased for my son and didn t want to relearn how to use it',
#  'this is our sixth or seventh kindle i forget we also have an ipads and ipod and iphone for the money i think the kindle is the best value for the buck',
#  'i really like the features back light and the speed compared to the older kindle versions from amazon',
#  'perfect size and amazing display clarity i have a tablet and the fire is more functional due to the better size',
#  'i love my new kindle hd i think you should send instructions on how to use it for people that are new to electronics like me my kindle does more then i ever knew it could',
#  'it is very very nice the only negative is that it is too heavy',
#  'i bought this for my wife but after checking it out i decided to keep it for myself its awesome so much more than reading books she has an older model kindle and loves it we also have a samsung galaxy tab but i like this kindle fire hd more',
#  'awesome just what i needed',
#  'i got this over the paperwhite because i read magazines and i wanted to see them in color other than that i would have preferred the paperwhite because of it s phenomenal battery life i m glad i got this one because the display is fantastic i have no complaints the battery is actually fine for my needs and there is something to be said for the color display silk browser is perfect for quickly downloading books from my local library and amazon',
#  'i ve always wanted a new tablet and this fit the bill perfectly not too large it has a nice resolution wonderful sound it does most of my apps that my phone does a lot better',
#  'it is our th and each version gets better and better fast responsive versatile',
#  'loving it',
#  'awesome inexpensive tablet',
#  'i bought this for my year old for his birthday',
#  'this was to replace my kindle fire that would not take a charge i mainly use it to read books check facebook and emails the new fire hd takes considerably longer to charge and does not last nearly as long i was very dissappointed when setting up facebook that i would have to agree that amazon could use my facebook account to make posts to my page and pages of my friends since when is this o k i liked my first kindle fire and this was being sold at an even better price i ve had it for weeks and it has frozen up times making me a little nervous of things to come',
#  'love the new features the camera could be improved but all in all i m satisfied with my purchase love the clarity of the display when playing games',
#  'my husband who is very critical loved his father s day gift very much fire hd will be a part of my gifts to others in the future',
#  'everything it says it is and more',
#  'i love it the color is awesome',
#  'wonderful to deal with',
#  'great christmas gift quick shipment',
#  'my year old loves it it was money well spent',
#  'screen cracked within weeks of purchase despite protective case would not recommend',
#  'amazon would not let me post my original review so here we go again i will leave out my full review my kindle arrived not packaged appropriately the device itself using over of the available gb storage for system files so keep that in mind when purchasing as this severely limits its functionality the app store is no where near good enough the touchscreen is jumpy not smooth so far support has been horrible',
#  'just getting into it but so far very good i love',
#  'the fire is a great product it is very user friendly and is the perfect size the price is extremely reasonable',
#  'great except i can t get candy crush soda to download',
#  'it s small and light enough to carry in my purse that s a big advantage over my very heavy laptop there are some things i m still trying to figure out but am working on it overall i really like it',
#  'exceeded my expectations initially i bought it just for email and office productivity it turned out to be a whole lot more there will be however some hooks from amazon marketing doesn t bother me really but they are there',
#  'ordered on dec st and it says still not shipped',
#  'i have been one of the earliest users of the kindle i like to read books and periodicals on the kindle when i get into bed at night i had the first one that amazon came out with it was a true workhorse and i had the one that they might have called the paperwhite with the controls on the sides but on the night before i was going on vacation i dropped it on the bathroom floor and it had screen problems because that unit was not repairable and no longer under warranty i waited a while when i saw this unit on sale sixty dollars off for with the free shipping for a new unit i jumped on it and took advantage of the one day sale it is a much more sophisticated unit that my previous models and the pictures are amazing i love the fact that it uses a standard type charger that we had with the blackberries and it also fits in the custom made case that someone had made me for the older unit i got great value on a great machine',
#  'great value wife loves it',
#  'very easy to learn and use i love it',
#  'love my new hd fire',
#  'i thought i was going to be able to download movies to watch on trips all of my attempts have been unsuccessful it no different from my older kindle',
#  'i love my kindle fire hd this was a christmas present from my mom in law i have been drooling over hers for a year very excited to have my own everything on this is user friendly easy to use large display and so much more everyone should have one of these',
#  'i am very pleased with my fire hd it performs all of the functions that i was hoping it is fast and easy to use i especially enjoy being able to take pictures with it and see them on my fire tv as well as carry them on the tablet or store them in the cloud it is very handy for that function as well as many others',
#  'this is my first tablet absolutely love it use it much more than i thought would',
#  'some differences from previous kindle still adjusting',
#  'my son loves this tablet much better than that kurio',
#  'i love everything about it except for the color although it s not a bad color not my favorite the rest is great',
#  'love the kindle fire th generation i couldn t have asked for a better product for',
#  'good amount of space but its very thick compared to the hdx',
#  'love it perfect for my kids',
#  'as a tablet it s great with one nasty little caveat the battery life is full on horrible and it can run itself down to nothing in the course of being left idle for hours so as usual alas it s a great idea with horrible execution around the place it was easy to save a buck it makes me sad but what are you gonna do it s okay for the price but the point of a tablet is not being chained to the wall',
#  'i had purchased this for a vacation i was taking with my grand daughter the fire hd didn t arrive as scheduled so i missed that for the entire vacation time i was extremely disappointed in that',
#  'the gb is not work it you have to get the gb if you want to have more than apps installed bought this for my yr old and he cant download his games he continues to use my tablet',
#  'i don t see any difference in the hd than the fire i have',
#  'we loved it so much that we bought a second',
#  'i received this as a christmas gift and am impressed with its ease of use functionality and touch sensitive screen the display is crisp i recommend this product for anyone looking for a small tablet first time user or otherwise',
#  'it turns out to be a good deal i m enjoying it',
#  'love my new kindle but hate that the ads are the first thing you see when you use it found out that you have to pay to get rid of the ads',
#  'the best tablet if you don t mind being attached wifi all the time or use very expensive mobile data of the app and games can t run without wifi so when there isn t any additional storage options not too much entertainment can go on',
#  'i love my new kindle fire',
#  'all i can say is great best money i ever spended',
#  'it would be nice if i did not have to purchase all books from amazon i have found several books for cheaper elsewhere',
#  'great device had little problem with navigating doing very well now',
#  'never had an issue with this kindle and after a year is still performing solidly',
#  'love the fact that i can my emails it is easy to read and lets you know how much time you have for the chapter had a regular kindle for four years but this is sooooo much better',
#  'i don t know where to complain i joined the waitlist for the prime day deal on this one was on the site and next thing i know the deal was done no notifications on the page or the phone app that is just wrong',
#  'love my new kindle fire hd my husband got it for me for christmas and i m so excited now i can read surf the web and order books all from the same device',
#  'absolutely beyond my expectations i m so glad i chose the kindle versus the ipad',
#  'loving it easy to use good pictures clear screen great item',
#  'spoiled by ipad this was a gift and i think we will adapt',
#  'the fire has meet my expectations and more i take it with me where ever i go play games and reading',
#  'this is a great device for the price you pay i bought this for my husband so he didn t keep using my ipad when i was using it i didn t want to spend that much for a second device so i chose this it has every app that he uses and is easy enough for him to use he really enjoys having his own tablet',
#  'it is great',
# ...
#  'okay product serves the purpose i use it for which is to read emails and search internet every now and then like the kindle much better',
#  'i am a former nook user i became increasingly unhappy with the lack of support for the nook hd i bought years ago especially after a software update a year ago caused a lot of issues with the device including problems with the battery life and difficulty downloading magazines my new kindle is fast and lightweight i only wish that i could transfer all of my e book purchases from the nook to my kindle because it is hard to go back to the buggy nook after reading on my kindle',
#  'it s an excellent value for the price can t stop finding new uses for it',
#  'easy to figure out and easy to use ready when arrived not real excited about signing on to aps to read a book but it is what it is not disappointed in the product',
#  'somewhat disappointed in the kindle fire the app s are outdated i was hoping to use this in place of my phone to surf the web play games etc all i do is read the ebooks i still use my phone or pc for everything else i should have bought the regular kindle and saved the money',
#  'what s not to love',
#  'this a good tablet with very nice display it satisfies my needs well the only reason for me not to give it stars is that the apps available are limited',
#  'i m very pleased with my fire hd i wish there was a case which made holding it easier to hold while reading if the case had a handle to hold on to it would be great i read in bed at night and it is hard to hold the kindle and click the pages by at the same time',
#  'great device bought two one for my year old and one for my year old easy to use and navigate the kids love them',
#  'i like this device for every reason except that to take full advantage of everything that it has to offer you need to subscribe to some of amazon s services while those services are not expensive the accumulated cost of those services can be an impact on fixed income seniors',
#  'i love reading on this kindle just the right size to hold in your hand and great on the eyes',
#  'this was my favorite kindle of all time and it finally died i am not happy with the replacement of a paperwhite',
#  'perfect for my yo mom for a first time tablet easy to navigate the screen is big enough easy to carry in her purse the reason i didn t give it stars is the quality of the pictures it s not as crisp as a samsung galaxy otherwise she s happy with it',
#  'i love it it s just the right size great price',
#  'very handy when you are waiting around',
#  'amazing product',
#  'better than i expected the sound is better than stereo i highly recommend this product',
#  'great product',
#  'the reason i bought this tablet was because i got tired of using the small screen on my cell phone i also ssw a presentation of the tablet on one of those home shopping shows which sold me on the hd ii am still learning about the tablet as i had some wifi issues in my area but things are now working out this product will also be shared with another family member',
#  'i love my new kindle use it everyday',
#  'easy shift from older kindle',
#  'great',
#  'i love my new kindle fire hd i had an older kindle fire but the camera was awful in that you could not adjust for rear face or front face it was so difficult to get pictures plus i was amazed at the clarity on the new kindle s screen hd definitely makes a difference i ve only been using it less than a week but i am in love',
#  'i was so disappointed that i could not see the picture in bright sunlight otherwise the item is terrific but i returned it because i specifically wanted to use it to read and other things while on my patio this summer i spoke w customer service and they suggested that i return it they could not help me so sad my nook has no problem in sunlight and i thought surely that the kindle would be the same the kindle does so much more than the nook',
#  'i received the original kindle fire a few years ago for mothers day and loved it i just got my new fire hd and love it even more i just don t like the connection for charging it s way too tight and difficult to access with the roocase cover on it despite the fact it said it was made specially for this exact unit same is true for the on off switch it slips under an edge of the cover and i cannot acceess it otherwise it s amazing',
#  'way cool and i love the color',
#  'i am very happy with my new kindle fire hd the colors and clarity are amazing',
#  'great buy and amazing product we have three now and want another',
#  'the kindle is so unintuitive to use i m returning and sticking with an ipad where should have gone to in the first place i am constantly having to google on how to do something with this thing complete waste of my time',
#  'slow to function heavier then i expected',
#  'love love love great tablet at at a fabulous price',
#  'just like magic you can do so many things with this device and such a reasonable price',
#  'you have to pay for just about everthing that you want on it it works ok convent size',
#  'excellent',
#  'i really like the fire the only issue i have is the battery discharges way faster then my original kindle fire even when i ve taken all of the battery conservation techniques also i really don t like that there isn t an indicator light that tells me when it s charging and when it s finished',
#  'this is my second fire hd i gave my first one to my year granddaughter',
#  'great tablet for the price',
#  'outstanding product easy to use',
#  'we thought this might be a little small but not the case the picture and audio is so good it blew us out of the water easy to use and hold i would recommend it to anyone oh and it is fast on wifi',
#  'like it but when i got it had intentions of getting kindle unlimited did not know they would not accept my debit card credit card required should of put that in bigger print after all the money amazon has got from that debit card for all the other purchases but not good enough for kindle unlimited',
#  'it wouldn t let me set up the time and date manually and the most annoying part is its automatic timezone options do not provide the correct date time they sent a replacement tablet and the same issue occurred i ve spent more than hours talking to the customer representative trying to fix the issue all of them ended up saying they needed to transfer the case to software developer to investigate and wanted me to wait for the response with similar price you can get an android tablet that s at least showing you the correct time and date i can t imagine how many more issues there would be with fire hd given that they couldn t even have a simple feature like date and time right',
#  'i was disappointed in the quality of the material i also wanted a cover that had a place that held the stylus overall a waste of money',
#  'love it works great screen so clear',
#  'a beautiful product was delivered in record time',
#  'i love my kindle fire it s easy to use',
#  'not everything i expected i like the color screen i wish there was a better way to organize my books didn t really want to bring all of then over from my kindle keyboard',
#  'love the kindle fire several of my friends have purchased one',
#  'love my fire hd lite enough to take anywhere and powerful enough to use for anything best christmas gift i received',
#  'i ve had it just over a week and it s been great love it all',
#  'unable to use for screenwriter s program disappointed',
#  'i received my fire hd days ago so i am still getting acquainted with it i can see already that i am going to like it this is my second kindle and i am loving the new features',
#  'stuck on fire screen amazon customer service tried to charge me for a second one complete waste of money do not buy',
#  'great product easy use especially for our yr old',
#  'it s good but not great you can t do any real computing on it just shopping some internetting and emailing also you can t download or use any non amazon apps on it',
#  'sweet little tablet',
#  'great i sure enjoy it',
#  'battery doesn t last as long as previous kindle',
#  'just perfect i love it the best',
#  'the gig storage would be a funny joke after owning for weeks two books and one app i get a your out of space message what they don t tell you is out of the gigs amazon takes at least of them app store takes another couple',
#  'i love it',
#  'this is my second kindle fire purchased as a replacement since i loved my first one till it was dropped not happy with this device at all battery won t even last a day my other kindle did not have this problem',
#  'so so i thought it will be faster it still needs more things to do',
#  'still learning how to use it and how it works a friend of mine loves it and i always wanted to get one as soon as i get it up and running i know i will enjoy it as much as my friend loves hers',
#  'everything we were expecting',
#  'so far i really like it i wish it could also get google play apps and i could change the background and lock screen pictures but other than that i really have no complaints as of yet',
#  'ok getting used to it',
#  'took time to get used to different format from old kindle fire but does a good job for my needs',
#  'received as a christmas gift less than a month later its screen shattered when it fell from the sofa onto the carpet poor build quality amazon did not stand behind the product poor customer service',
#  'really like it just the right size for me wish that the instructions were better',
#  'love it arrived on time',
#  'great tablet',
#  'worked right out of the box easy to use except for where did they hide the on off button feels heavier and thicker than my previous hdx fire i d recommend this',
#  'this is my second kindle fire i purchased the original kindle fire and have since picked up the fire hd and really like the improved scene resolution and overall performance of this model compared to the previous model both of them were purchased for my teenage daughter and she couldn t be happier i have asked her if she would like to try another tablet by someone else but she says she has played around with her friends tablets and she like her kindle better no real reason she just does',
#  'it s ok some sounds are not very good at all like the alarm for the clock card games are slow free games are not really free',
#  'wow i absolutely love it it s like a mini computer with so many functions not only for reading books the quality and clarity of the picture is amazing i would definitely recommend this product',
#  'so far a great tablet of my use has been for pleasure reading sometimes using text to speech that has been improved tremendously over original kindle very natural speech tones and inflections i am very pleased with my purchase',
#  'we love our kindle fire hd and we use it all the time and it just so awsome',
#  'it was a gift for my husband he has really enjoyed it',
#  'thank you i received well',
#  'pretty good',
#  'bought for wife she loves its flexibility',
#  'i upgraded from a first gen kindle fire with this and this one is a huge upgrade from that games run better reading is easier because of the weight difference netflix and hulu look great compared to my last one even the sound is better the cameras are not that great but you really do not buy a kindle for the camera i have a windows phone which takes excellent photos so really the cameras are just an extra i mainly use my kindle to read and occasionally watch shows on lately i have used it more and more to surf the web my poor pc just collects dust anymore i am very satisfied with this product could not be happier',
#  'i don t know why i waited so long to get a kindle fire tablet i m really loving the speed and convenience of the tablet it s everything that i wanted',
#  'works very well',
#  'i love this device it is so much lighter than the previous model it is so fast and sharp perfect in every way resolution fantastic',
#  'more than i expected still learning how to use it since i am an almost senior citizen i love the pink case',
#  'i love my fire hd',
#  'the only problem is the charging port is not strong enough for teens to use it',
#  'great for kids sturdy and doesn t need a case they are truly kid proof love the kindle fires',
#  'this is a gift for my yr old son i ordered this a few weeks ago and got it quick i ve been playing with it downloading apps playing some of the games etc and i love it i bought this hoping to help him improve in his reading i honestly think he s going to love it',
#  'my new fire hd works great the colors are bright beautiful and sharp i use it everyday to watch videos and read books and programs i also bought one for my year old grandson last fall and he loves his too the construction of these kindles is very sturdy and solid i have a new laptop and other tablets but i prefer using my kindle fire so i only use the others occasionly',
#  'arrived fast so far excellent i have been using the original kindle fire for years with no troubles and gifted it to my hubby when my new kindle arrived',
#  'love it',
#  'am getting to know new features that are different from previous hd but so far love it i really love that it has a camera',
#  'i am very please with my kindle fire hd the screen size is outstanding for games and also reading your book i give mine stars it is awesome just to click and shop i recommend it highly just my personal opinion but very happy with my product',
#  'i ve had all the kindles they are all great in their own way especially love the speakers and picture quality of the fire have been an amazon prime member for a long time and the deals have saved me hundreds can t go wrong with any kindle',
#  'it s too awesome i want to thank everyone who helped me even my dad thank u so much',
#  'so far this has been a really good tablet',
#  'love love this fire hd so happy that i bought it',
#  'fine product no problems',
#  'need instructions',
#  'very easy to use and figure out great for reading',
#  'haven t used it much yet but seems to be easy to navigate',
#  'great product',
#  'wish you could get other apps beside just amazon apps',
#  'excellent',
#  'so so',
#  'love my new kindle',
#  'i had the first kindle and upgraded finally and love it',
#  'as described arrived in great time',
#  'love it great tablet would recommend',
#  'had a kindle for years but love my new kindle fire',
#  'nice size and lighter than my old kindle i am hoping that kindles s charging port issues have been resolved i am holding my judgment till i see how this issue goes',
#  'first one froze a week after purchase so far so good on the nd one my year old little girl loves the tablet and i like the automatic parental controls based on age of the user',
#  'i had wanted a tablet for a long time and i am very happy with the kindle fire i think it is the best value around',
#  'love it',
#  'i only paid but now that i have it i would have paid full price if i would have had to',
#  'i love it',
#  'very satisfied as always',
#  'why is it that amazons website doesn t work right on its own kindle products it took me twenty minutes to even get here to write this slow page loads the keypad wont come up when you click in the search box you finally do get to the search box and the stupid page scrolls down so you cant see what you are typing plus if you download their app instead and use that the pages don t list all the used options for products like books its insane',
#  'great value purchased for my spouse and she is enjoying it',
#  'this was a great surprise for christmas it is a great size easy to pack around and does everything i need it to do',
#  'i just wanted a replacement for my original kindle but this one is way too complicated and i still don t know how to access my books someone who needs internet email and tablet or laptop type capability will love it for me a simple kindle replacement would have been preferable',
#  ...]

# %%
# Convert a collection of raw documents to a matrix of TF-IDF features. This is required so as to train the model using features instead of
# raw strings.
tvec = TfidfVectorizer(use_idf=True,
strip_accents='ascii')

X_train_tvec = tvec.fit_transform(X_train_cleaned)

# %%
121# Support Vector Classifier model
svr_lin = LinearSVC(multi_class='ovr',C=1.0,loss='squared_hinge', dual=False)
svr_lin.fit(X_train_tvec, Y_train)
# Out:
# LinearSVC(dual=False)

# %%
# Predict using training and testing data and display the accuracy, f-1 score, precision for Positive and Negative Sentiment Classifiers
svr_lin_predictions = svr_lin.predict(tvec.transform(X_test_cleaned))
report = classification_report(Y_test,svr_lin_predictions, output_dict=True)
data_report = pd.DataFrame(report).transpose().round(2)
cm = sns.light_palette("yellow", as_cmap=True)
data_report.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_4536f_row0_col0, #T_4536f_row0_col1, #T_4536f_row0_col2, #T_4536f_row2_col3 {
#   background-color: #f2f2dd;
#   color: #000000;
# }
# #T_4536f_row0_col3 {
#   background-color: #f4f4b9;
#   color: #000000;
# }
# #T_4536f_row1_col0, #T_4536f_row1_col1, #T_4536f_row1_col2, #T_4536f_row3_col3, #T_4536f_row4_col3 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_4536f_row1_col3 {
#   background-color: #fdfd24;
#   color: #000000;
# }
# #T_4536f_row2_col0 {
#   background-color: #fdfd1c;
#   color: #000000;
# }
# #T_4536f_row2_col1, #T_4536f_row4_col1 {
#   background-color: #fdfd21;
#   color: #000000;
# }
# #T_4536f_row2_col2 {
#   background-color: #fdfd22;
#   color: #000000;
# }
# #T_4536f_row3_col0 {
#   background-color: #f8f86f;
#   color: #000000;
# }
# #T_4536f_row3_col1 {
#   background-color: #f9f96c;
#   color: #000000;
# }
# #T_4536f_row3_col2 {
#   background-color: #f9f96e;
#   color: #000000;
# }
# #T_4536f_row4_col0 {
#   background-color: #fdfd2a;
#   color: #000000;
# }
# #T_4536f_row4_col2 {
#   background-color: #fdfd2b;
#   color: #000000;
# }
# </style>
# <table id="T_4536f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4536f_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_4536f_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_4536f_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_4536f_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4536f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4536f_row0_col0" class="data row0 col0" >0.770000</td>
#       <td id="T_4536f_row0_col1" class="data row0 col1" >0.630000</td>
#       <td id="T_4536f_row0_col2" class="data row0 col2" >0.690000</td>
#       <td id="T_4536f_row0_col3" class="data row0 col3" >1018.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4536f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4536f_row1_col0" class="data row1 col0" >0.930000</td>
#       <td id="T_4536f_row1_col1" class="data row1 col1" >0.960000</td>
#       <td id="T_4536f_row1_col2" class="data row1 col2" >0.950000</td>
#       <td id="T_4536f_row1_col3" class="data row1 col3" >5152.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4536f_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_4536f_row2_col0" class="data row2 col0" >0.910000</td>
#       <td id="T_4536f_row2_col1" class="data row2 col1" >0.910000</td>
#       <td id="T_4536f_row2_col2" class="data row2 col2" >0.910000</td>
#       <td id="T_4536f_row2_col3" class="data row2 col3" >0.910000</td>
#     </tr>
#     <tr>
#       <th id="T_4536f_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_4536f_row3_col0" class="data row3 col0" >0.850000</td>
#       <td id="T_4536f_row3_col1" class="data row3 col1" >0.800000</td>
#       <td id="T_4536f_row3_col2" class="data row3 col2" >0.820000</td>
#       <td id="T_4536f_row3_col3" class="data row3 col3" >6170.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4536f_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_4536f_row4_col0" class="data row4 col0" >0.900000</td>
#       <td id="T_4536f_row4_col1" class="data row4 col1" >0.910000</td>
#       <td id="T_4536f_row4_col2" class="data row4 col2" >0.900000</td>
#       <td id="T_4536f_row4_col3" class="data row4 col3" >6170.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#confusion matrix
svr_lin_predictions=svr_lin.predict(tvec.transform(X_test_cleaned))
ax= plt.subplot()
cm=confusion_matrix(Y_test,svr_lin_predictions)
sns.heatmap(cm, annot=True, fmt='g', ax=ax,cmap='Greens');
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['negative', 'positive']); ax.yaxis.set_ticklabels(['negative', 'positive']);

# %%
# testing the model with sample 'Negative' review
demo_review = np.array([' suscitated it was very inexpensive so i did not want to pay half again the price to ship it back for an exchange so the company would do nothing when they sent me an inquiry as to product satisfaction'])
demo_review_X_test = tvec.transform(demo_review)
print(svr_lin.predict(demo_review_X_test))
# Out:
# [0]

# %%
# testing the model with sample 'Positive' review
demo_review_2 = np.array(['Excellent product. Works well and performs as expected.'])
demo_review_X_test_2 = tvec.transform(demo_review_2)
print(svr_lin.predict(demo_review_X_test_2))

# expected output = 1 (Positive)
# actual output = 1 (Positive)
# Out:
# [1]

# %%
# Random Forest model
random_forest = RandomForestClassifier()
random_forest.fit(X_train_tvec, Y_train)
# Out:
# RandomForestClassifier()

# %%
# Predict using training and testing data and display the accuracy, f-1 score, precision for Positive and Negative Sentiment Classifiers
ranfrst_predictions = random_forest.predict(tvec.transform(X_test_cleaned))
report = classification_report(Y_test,ranfrst_predictions, output_dict=True)
data_report = pd.DataFrame(report).transpose().round(2)
cm = sns.light_palette("red", as_cmap=True)
data_report.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_06953_row0_col0, #T_06953_row0_col1, #T_06953_row0_col2, #T_06953_row2_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_06953_row0_col3 {
#   background-color: #f5c8c8;
#   color: #000000;
# }
# #T_06953_row1_col0, #T_06953_row1_col1, #T_06953_row1_col2, #T_06953_row2_col0, #T_06953_row3_col3, #T_06953_row4_col0, #T_06953_row4_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_06953_row1_col3, #T_06953_row2_col1, #T_06953_row4_col1 {
#   background-color: #fd2828;
#   color: #f1f1f1;
# }
# #T_06953_row2_col2 {
#   background-color: #fe1c1c;
#   color: #f1f1f1;
# }
# #T_06953_row3_col0 {
#   background-color: #fb5050;
#   color: #f1f1f1;
# }
# #T_06953_row3_col1 {
#   background-color: #f97979;
#   color: #f1f1f1;
# }
# #T_06953_row3_col2 {
#   background-color: #f97a7a;
#   color: #f1f1f1;
# }
# #T_06953_row4_col2 {
#   background-color: #fd2a2a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_06953" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06953_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_06953_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_06953_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_06953_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06953_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06953_row0_col0" class="data row0 col0" >0.840000</td>
#       <td id="T_06953_row0_col1" class="data row0 col1" >0.280000</td>
#       <td id="T_06953_row0_col2" class="data row0 col2" >0.420000</td>
#       <td id="T_06953_row0_col3" class="data row0 col3" >1018.000000</td>
#     </tr>
#     <tr>
#       <th id="T_06953_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_06953_row1_col0" class="data row1 col0" >0.870000</td>
#       <td id="T_06953_row1_col1" class="data row1 col1" >0.990000</td>
#       <td id="T_06953_row1_col2" class="data row1 col2" >0.930000</td>
#       <td id="T_06953_row1_col3" class="data row1 col3" >5152.000000</td>
#     </tr>
#     <tr>
#       <th id="T_06953_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_06953_row2_col0" class="data row2 col0" >0.870000</td>
#       <td id="T_06953_row2_col1" class="data row2 col1" >0.870000</td>
#       <td id="T_06953_row2_col2" class="data row2 col2" >0.870000</td>
#       <td id="T_06953_row2_col3" class="data row2 col3" >0.870000</td>
#     </tr>
#     <tr>
#       <th id="T_06953_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_06953_row3_col0" class="data row3 col0" >0.860000</td>
#       <td id="T_06953_row3_col1" class="data row3 col1" >0.630000</td>
#       <td id="T_06953_row3_col2" class="data row3 col2" >0.670000</td>
#       <td id="T_06953_row3_col3" class="data row3 col3" >6170.000000</td>
#     </tr>
#     <tr>
#       <th id="T_06953_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_06953_row4_col0" class="data row4 col0" >0.870000</td>
#       <td id="T_06953_row4_col1" class="data row4 col1" >0.870000</td>
#       <td id="T_06953_row4_col2" class="data row4 col2" >0.840000</td>
#       <td id="T_06953_row4_col3" class="data row4 col3" >6170.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# confusion matrix
ranfrst_predictions=random_forest.predict(tvec.transform(X_test_cleaned))
ax= plt.subplot()
cm=confusion_matrix(Y_test,ranfrst_predictions)
sns.heatmap(cm, annot=True, fmt='g', ax=ax,cmap='Oranges');
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['negative', 'positive']); ax.yaxis.set_ticklabels(['negative', 'positive']);

# %%
# K-Nearest Neighbor model
knn = KNeighborsClassifier(n_neighbors=5,metric='minkowski',p=2)
knn.fit(X_train_tvec, Y_train)
# Out:
# KNeighborsClassifier()

# %%
# Predict using training and testing data and display the accuracy, f-1 score, precision for Positive and Negative Sentiment Classifiers
knn_predictions = knn.predict(tvec.transform(X_test_cleaned))
report = classification_report(Y_test,knn_predictions, output_dict=True)
data_report = pd.DataFrame(report).transpose().round(2)
cm = sns.light_palette("gray", as_cmap=True)
data_report.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_21267_row0_col0, #T_21267_row0_col1, #T_21267_row0_col2, #T_21267_row2_col3 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_21267_row0_col3 {
#   background-color: #dedede;
#   color: #000000;
# }
# #T_21267_row1_col0, #T_21267_row1_col1, #T_21267_row1_col2, #T_21267_row2_col0, #T_21267_row3_col3, #T_21267_row4_col3 {
#   background-color: #808080;
#   color: #f1f1f1;
# }
# #T_21267_row1_col3, #T_21267_row2_col1, #T_21267_row4_col1, #T_21267_row4_col2 {
#   background-color: #939393;
#   color: #f1f1f1;
# }
# #T_21267_row2_col2 {
#   background-color: #898989;
#   color: #f1f1f1;
# }
# #T_21267_row3_col0, #T_21267_row3_col2 {
#   background-color: #b8b8b8;
#   color: #000000;
# }
# #T_21267_row3_col1 {
#   background-color: #b9b9b9;
#   color: #000000;
# }
# #T_21267_row4_col0 {
#   background-color: #979797;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_21267" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21267_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_21267_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_21267_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_21267_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21267_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21267_row0_col0" class="data row0 col0" >0.740000</td>
#       <td id="T_21267_row0_col1" class="data row0 col1" >0.030000</td>
#       <td id="T_21267_row0_col2" class="data row0 col2" >0.060000</td>
#       <td id="T_21267_row0_col3" class="data row0 col3" >1018.000000</td>
#     </tr>
#     <tr>
#       <th id="T_21267_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_21267_row1_col0" class="data row1 col0" >0.840000</td>
#       <td id="T_21267_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_21267_row1_col2" class="data row1 col2" >0.910000</td>
#       <td id="T_21267_row1_col3" class="data row1 col3" >5152.000000</td>
#     </tr>
#     <tr>
#       <th id="T_21267_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_21267_row2_col0" class="data row2 col0" >0.840000</td>
#       <td id="T_21267_row2_col1" class="data row2 col1" >0.840000</td>
#       <td id="T_21267_row2_col2" class="data row2 col2" >0.840000</td>
#       <td id="T_21267_row2_col3" class="data row2 col3" >0.840000</td>
#     </tr>
#     <tr>
#       <th id="T_21267_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_21267_row3_col0" class="data row3 col0" >0.790000</td>
#       <td id="T_21267_row3_col1" class="data row3 col1" >0.510000</td>
#       <td id="T_21267_row3_col2" class="data row3 col2" >0.490000</td>
#       <td id="T_21267_row3_col3" class="data row3 col3" >6170.000000</td>
#     </tr>
#     <tr>
#       <th id="T_21267_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_21267_row4_col0" class="data row4 col0" >0.820000</td>
#       <td id="T_21267_row4_col1" class="data row4 col1" >0.840000</td>
#       <td id="T_21267_row4_col2" class="data row4 col2" >0.770000</td>
#       <td id="T_21267_row4_col3" class="data row4 col3" >6170.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# confusion matrix
knn_predictions=knn.predict(tvec.transform(X_test_cleaned))
ax= plt.subplot()
cm=confusion_matrix(Y_test,knn_predictions)
sns.heatmap(cm, annot=True, fmt='g', ax=ax,cmap='Reds');
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['negative', 'positive']); ax.yaxis.set_ticklabels(['negative', 'positive']);

# %%
# Logistic regression model
lr = LogisticRegression()
lr.fit(X_train_tvec, Y_train)
# Out:
# LogisticRegression()

# %%
lr_predictions=lr.predict(tvec.transform(X_test_cleaned))
cm = confusion_matrix(Y_test, lr_predictions)
ax= plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax,cmap='Blues');
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['negative', 'positive']); ax.yaxis.set_ticklabels(['negative', 'positive']);

# %%
lr_predictions=lr.predict(tvec.transform(X_test_cleaned))
report = classification_report(Y_test,lr_predictions, output_dict=True)
data_report = pd.DataFrame(report).transpose().round(2)
cm = sns.light_palette("blue", as_cmap=True)
data_report.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_c662f_row0_col0, #T_c662f_row0_col1, #T_c662f_row0_col2, #T_c662f_row2_col3 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_c662f_row0_col3 {
#   background-color: #c9c9f5;
#   color: #000000;
# }
# #T_c662f_row1_col0, #T_c662f_row1_col1, #T_c662f_row1_col2, #T_c662f_row3_col3, #T_c662f_row4_col3 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_c662f_row1_col3 {
#   background-color: #2828fd;
#   color: #f1f1f1;
# }
# #T_c662f_row2_col0 {
#   background-color: #1212fe;
#   color: #f1f1f1;
# }
# #T_c662f_row2_col1, #T_c662f_row4_col1 {
#   background-color: #2626fd;
#   color: #f1f1f1;
# }
# #T_c662f_row2_col2 {
#   background-color: #2323fd;
#   color: #f1f1f1;
# }
# #T_c662f_row3_col0 {
#   background-color: #6f6ff9;
#   color: #f1f1f1;
# }
# #T_c662f_row3_col1 {
#   background-color: #7878f9;
#   color: #f1f1f1;
# }
# #T_c662f_row3_col2 {
#   background-color: #7c7cf9;
#   color: #f1f1f1;
# }
# #T_c662f_row4_col0 {
#   background-color: #2525fd;
#   color: #f1f1f1;
# }
# #T_c662f_row4_col2 {
#   background-color: #2c2cfd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c662f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c662f_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_c662f_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_c662f_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_c662f_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c662f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c662f_row0_col0" class="data row0 col0" >0.790000</td>
#       <td id="T_c662f_row0_col1" class="data row0 col1" >0.590000</td>
#       <td id="T_c662f_row0_col2" class="data row0 col2" >0.680000</td>
#       <td id="T_c662f_row0_col3" class="data row0 col3" >1018.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c662f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c662f_row1_col0" class="data row1 col0" >0.920000</td>
#       <td id="T_c662f_row1_col1" class="data row1 col1" >0.970000</td>
#       <td id="T_c662f_row1_col2" class="data row1 col2" >0.950000</td>
#       <td id="T_c662f_row1_col3" class="data row1 col3" >5152.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c662f_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_c662f_row2_col0" class="data row2 col0" >0.910000</td>
#       <td id="T_c662f_row2_col1" class="data row2 col1" >0.910000</td>
#       <td id="T_c662f_row2_col2" class="data row2 col2" >0.910000</td>
#       <td id="T_c662f_row2_col3" class="data row2 col3" >0.910000</td>
#     </tr>
#     <tr>
#       <th id="T_c662f_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_c662f_row3_col0" class="data row3 col0" >0.860000</td>
#       <td id="T_c662f_row3_col1" class="data row3 col1" >0.780000</td>
#       <td id="T_c662f_row3_col2" class="data row3 col2" >0.810000</td>
#       <td id="T_c662f_row3_col3" class="data row3 col3" >6170.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c662f_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_c662f_row4_col0" class="data row4 col0" >0.900000</td>
#       <td id="T_c662f_row4_col1" class="data row4 col1" >0.910000</td>
#       <td id="T_c662f_row4_col2" class="data row4 col2" >0.900000</td>
#       <td id="T_c662f_row4_col3" class="data row4 col3" >6170.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
X_test
# Out:
#       marketplace  customer_id       review_id  product_id  product_parent  \
# 29301          US     14838102   R7IJPG60A4VWG  B00IKPYKWG         2693241
# 19920          US      1191454  R2OOV5F4V6BSR3  B00IKPW0UA         2693241
# 17408          US     37457316  R2FEWTUJ7VLR8Q  B00IKPYKWG         2693241
# 2898           US     48533314  R35Y6OTXB0YJOH  B00IKPZ5V6         2693241
# 22257          US     19313349  R284PYAQNLCDZX  B00IKPYKWG         2693241
# ...           ...          ...             ...         ...             ...
# 15448          US      8507185  R30CK5OQ0BX1QP  B00IKPYKWG         2693241
# 1009           US     47386214   RTO0B2P8MV0JX  B00IKPZ5V6         2693241
# 24705          US      1471625  R1RH2BRTWM6BI5  B00IKPYKWG         2693241
# 26320          US     21185945  R1SKVYV6483YW6  B00IKPW0UA         2693241
# 4306           US     22959081  R3PVFAN5XKFQ1L  B00LCHWEPE         2693241
#
#                                product_title product_category  star_rating  \
# 29301  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            4
# 19920  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 17408  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 2898   Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 22257  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            4
# ...                                      ...              ...          ...
# 15448  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            4
# 1009   Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 24705  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 26320  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 4306   Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
#
#        helpful_votes  total_votes vine verified_purchase  \
# 29301              8            8    N                 N
# 19920              0            0    N                 Y
# 17408              0            0    N                 Y
# 2898               1            1    N                 N
# 22257              0            0    N                 Y
# ...              ...          ...  ...               ...
# 15448              0            0    N                 Y
# 1009               0            0    N                 Y
# 24705              0            0    N                 Y
# 26320              1            1    N                 Y
# 4306               0            0    N                 Y
#
#                         review_headline  \
# 29301                Good but not great
# 19920                        Five Stars
# 17408                        great deal
# 2898                         Five Stars
# 22257                   nice and useful
# ...                                 ...
# 15448                          addicted
# 1009          Great gift, even for dads
# 24705                             Great
# 26320         great apps to choose from
# 4306   Lightweight & Great Battery Life
#
#                                              review_body review_date
# 29301  I would give this 5 stars but the frustration ...  30-11-2014
# 19920                                            perfect  11-01-2015
# 17408              It does everything that is advertised  28-01-2015
# 2898                               My husband loves it !  15-07-2015
# 22257  I like this Kindle. It's easy to use and the l...  05-01-2015
# ...                                                  ...         ...
# 15448                                           Love it!  16-02-2015
# 1009   My wife got this for my birthday,  I stayed up...  12-08-2015
# 24705  It is a great iteam the only down size is that...  02-01-2015
# 26320  I'm really enjoying my Fire HD 7! Definitely a...  24-12-2014
# 4306   Lightweight and easy to read. So far it has gr...  23-06-2015
#
# [6170 rows x 15 columns]

# %%
Testing_Output=X_test

# %%
Testing_Output['Review']=svr_lin_predictions

# %%
Testing_Output
# Out:
#       marketplace  customer_id       review_id  product_id  product_parent  \
# 29301          US     14838102   R7IJPG60A4VWG  B00IKPYKWG         2693241
# 19920          US      1191454  R2OOV5F4V6BSR3  B00IKPW0UA         2693241
# 17408          US     37457316  R2FEWTUJ7VLR8Q  B00IKPYKWG         2693241
# 2898           US     48533314  R35Y6OTXB0YJOH  B00IKPZ5V6         2693241
# 22257          US     19313349  R284PYAQNLCDZX  B00IKPYKWG         2693241
# ...           ...          ...             ...         ...             ...
# 15448          US      8507185  R30CK5OQ0BX1QP  B00IKPYKWG         2693241
# 1009           US     47386214   RTO0B2P8MV0JX  B00IKPZ5V6         2693241
# 24705          US      1471625  R1RH2BRTWM6BI5  B00IKPYKWG         2693241
# 26320          US     21185945  R1SKVYV6483YW6  B00IKPW0UA         2693241
# 4306           US     22959081  R3PVFAN5XKFQ1L  B00LCHWEPE         2693241
#
#                                product_title product_category  star_rating  \
# 29301  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            4
# 19920  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 17408  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 2898   Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 22257  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            4
# ...                                      ...              ...          ...
# 15448  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            4
# 1009   Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 24705  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 26320  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 4306   Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
#
#        helpful_votes  total_votes vine verified_purchase  \
# 29301              8            8    N                 N
# 19920              0            0    N                 Y
# 17408              0            0    N                 Y
# 2898               1            1    N                 N
# 22257              0            0    N                 Y
# ...              ...          ...  ...               ...
# 15448              0            0    N                 Y
# 1009               0            0    N                 Y
# 24705              0            0    N                 Y
# 26320              1            1    N                 Y
# 4306               0            0    N                 Y
#
#                         review_headline  \
# 29301                Good but not great
# 19920                        Five Stars
# 17408                        great deal
# 2898                         Five Stars
# 22257                   nice and useful
# ...                                 ...
# 15448                          addicted
# 1009          Great gift, even for dads
# 24705                             Great
# 26320         great apps to choose from
# 4306   Lightweight & Great Battery Life
#
#                                              review_body review_date  Review
# 29301  I would give this 5 stars but the frustration ...  30-11-2014       0
# 19920                                            perfect  11-01-2015       1
# 17408              It does everything that is advertised  28-01-2015       1
# 2898                               My husband loves it !  15-07-2015       1
# 22257  I like this Kindle. It's easy to use and the l...  05-01-2015       1
# ...                                                  ...         ...     ...
# 15448                                           Love it!  16-02-2015       1
# 1009   My wife got this for my birthday,  I stayed up...  12-08-2015       1
# 24705  It is a great iteam the only down size is that...  02-01-2015       1
# 26320  I'm really enjoying my Fire HD 7! Definitely a...  24-12-2014       1
# 4306   Lightweight and easy to read. So far it has gr...  23-06-2015       1
#
# [6170 rows x 16 columns]

# %%
Testing_Output['Review'] = Testing_Output['Review'].replace({1: 'Positive', 0: 'Negative'})

# %%
Testing_Output
# Out:
#       marketplace  customer_id       review_id  product_id  product_parent  \
# 29301          US     14838102   R7IJPG60A4VWG  B00IKPYKWG         2693241
# 19920          US      1191454  R2OOV5F4V6BSR3  B00IKPW0UA         2693241
# 17408          US     37457316  R2FEWTUJ7VLR8Q  B00IKPYKWG         2693241
# 2898           US     48533314  R35Y6OTXB0YJOH  B00IKPZ5V6         2693241
# 22257          US     19313349  R284PYAQNLCDZX  B00IKPYKWG         2693241
# ...           ...          ...             ...         ...             ...
# 15448          US      8507185  R30CK5OQ0BX1QP  B00IKPYKWG         2693241
# 1009           US     47386214   RTO0B2P8MV0JX  B00IKPZ5V6         2693241
# 24705          US      1471625  R1RH2BRTWM6BI5  B00IKPYKWG         2693241
# 26320          US     21185945  R1SKVYV6483YW6  B00IKPW0UA         2693241
# 4306           US     22959081  R3PVFAN5XKFQ1L  B00LCHWEPE         2693241
#
#                                product_title product_category  star_rating  \
# 29301  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            4
# 19920  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 17408  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 2898   Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 22257  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            4
# ...                                      ...              ...          ...
# 15448  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            4
# 1009   Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 24705  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 26320  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 4306   Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
#
#        helpful_votes  total_votes vine verified_purchase  \
# 29301              8            8    N                 N
# 19920              0            0    N                 Y
# 17408              0            0    N                 Y
# 2898               1            1    N                 N
# 22257              0            0    N                 Y
# ...              ...          ...  ...               ...
# 15448              0            0    N                 Y
# 1009               0            0    N                 Y
# 24705              0            0    N                 Y
# 26320              1            1    N                 Y
# 4306               0            0    N                 Y
#
#                         review_headline  \
# 29301                Good but not great
# 19920                        Five Stars
# 17408                        great deal
# 2898                         Five Stars
# 22257                   nice and useful
# ...                                 ...
# 15448                          addicted
# 1009          Great gift, even for dads
# 24705                             Great
# 26320         great apps to choose from
# 4306   Lightweight & Great Battery Life
#
#                                              review_body review_date    Review
# 29301  I would give this 5 stars but the frustration ...  30-11-2014  Negative
# 19920                                            perfect  11-01-2015  Positive
# 17408              It does everything that is advertised  28-01-2015  Positive
# 2898                               My husband loves it !  15-07-2015  Positive
# 22257  I like this Kindle. It's easy to use and the l...  05-01-2015  Positive
# ...                                                  ...         ...       ...
# 15448                                           Love it!  16-02-2015  Positive
# 1009   My wife got this for my birthday,  I stayed up...  12-08-2015  Positive
# 24705  It is a great iteam the only down size is that...  02-01-2015  Positive
# 26320  I'm really enjoying my Fire HD 7! Definitely a...  24-12-2014  Positive
# 4306   Lightweight and easy to read. So far it has gr...  23-06-2015  Positive
#
# [6170 rows x 16 columns]

# %%
Testing_Output.columns
# Out:
# Index(['marketplace', 'customer_id', 'review_id', 'product_id',
#        'product_parent', 'product_title', 'product_category', 'star_rating',
#        'helpful_votes', 'total_votes', 'vine', 'verified_purchase',
#        'review_headline', 'review_body', 'review_date', 'Review'],
#       dtype='object')

# %%
# Replace with your actual connection string
connection_string = 'DefaultEndpointsProtocol=https;AccountName=datalake779;AccountKey=jSCEsnJyJ70MTvBJ3xaL2YyhHZPDNE4UbFyQGUhx3FfKbhZo4/mqNqM+yYImULMsE2MFtHrTKrZL+ASt/XfvFA==;EndpointSuffix=core.windows.net'
container_name = 'sentianalysis'
blob_name = 'testing_output.csv'  # The name you want to give to your blob



# Convert DataFrame to CSV
csv_data = Testing_Output.to_csv(index=False)

# Create a BlobServiceClient object
blob_service_client = BlobServiceClient.from_connection_string(connection_string)

# Create a BlobClient to interact with the specific blob
blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)

# Upload the CSV data to the blob
blob_client.upload_blob(csv_data, overwrite=True)

print(f"Data uploaded to {container_name}/{blob_name}")
# Out:
# Data uploaded to sentianalysis/testing_output.csv
